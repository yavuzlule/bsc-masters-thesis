# %% [markdown]
# # Visualizations (UMAP)
# This notebook contains all of my work on visualizations of book embeddings.

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# ## 1. Auxiliary Functions

# %% [markdown]
# ## 2. Preprocess the dataset

# %% [markdown]
# ## 4. Obtain 2D visualizations (UMAP)
